# %%
# !pip uninstall tensorflow
# !pip install tensorflow==2.16.1

# %%
import tensorflow as tf
import os
import numpy as np
from osgeo import gdal, osr
import cv2
import matplotlib.pyplot as plt

# %%
def input_pipeline(filename, batch_size, is_shuffle=True, is_train=True, is_repeat=True):
    feature_description = {
        'image_raw': tf.io.FixedLenFeature([400*400*4], dtype=tf.int64),
        'label': tf.io.FixedLenFeature([400*400*1], dtype=tf.int64),
    }

    def _parse_function(example_proto):
        feature_dict = tf.io.parse_single_example(example_proto, feature_description)
        image = tf.reshape(feature_dict['image_raw'], [400, 400, 4])
        image = tf.cast(image, tf.float32)

        image = image/10000

        label = tf.reshape(feature_dict['label'], [400, 400, 1])
        label = tf.cast(label, tf.float32)

        image_label = tf.concat([image, label], axis=-1)
        if is_train:
            image_label = tf.image.rot90(image_label, tf.random.uniform([], 0, 5, dtype=tf.int32))
            image_label = tf.image.random_flip_left_right(image_label)
            image_label = tf.image.random_flip_up_down(image_label)

        image = image_label[:, :, :4]
        label = image_label[:, :, -1]

        label = tf.cast(label, tf.int32)

        return image, label

    dataset = tf.data.TFRecordDataset(filename)
    if is_repeat:
        dataset = dataset.repeat()
    dataset = dataset.map(_parse_function)
    if is_shuffle:
        dataset = dataset.shuffle(buffer_size=1000)
    batch = dataset.batch(batch_size=batch_size)
    return batch

# %%
def P(X, F1, k_size, s, stage):

    # Name definition
    P_Name = 'P-layer' + str(stage)
    P_BN_Name = 'P-layer-BN' + str(stage)

    X = tf.keras.layers.Conv2D(filters = F1, kernel_size = (k_size, k_size), strides = (s, s), padding = 'valid',
              name = P_Name, kernel_initializer = tf.keras.initializers.glorot_uniform(seed = 0))(X)

    X = tf.keras.layers.BatchNormalization(axis = 3, name = P_BN_Name)(X)

    X = tf.keras.layers.Activation('relu')(X)

    return X

def Q(X, F1, k_size, s, stage):

    # Name definition
    Q_Name = 'Q-layer' + str(stage)
    Q_BN_Name = 'Q-layer-BN' + str(stage)


    X = tf.keras.layers.Conv2D(filters = F1, kernel_size = (k_size, k_size), strides = (s, s), padding = 'same',
              name = Q_Name, kernel_initializer = tf.keras.initializers.glorot_uniform(seed = 0))(X)

    X = tf.keras.layers.BatchNormalization(axis = 3, name = Q_BN_Name)(X)

    X = tf.keras.layers.Activation('relu')(X)

    return X

# w = h = 128

def complex_initializer(base_initializer):
    f = base_initializer(seed = 0)

    def initializer(*args, dtype=tf.complex64, **kwargs):
        real = f(*args, **kwargs)
        imag = f(*args, **kwargs)
        return tf.complex(real, imag)

    return initializer


class FourierLayer_large(tf.keras.layers.Layer):
    def __init__(self, num_modes, stage, L=1.0):
        super(FourierLayer_large, self).__init__()
        self.num_modes = num_modes
        self.modes1=24
        self.modes2=24
        self.L = L
        self.stage = stage

    def build(self, input_shape):
        self.weight1 = self.add_weight(
            shape=(input_shape[-1], self.num_modes, self.modes1, self.modes2), dtype=tf.complex64,
            initializer = complex_initializer(tf.keras.initializers.glorot_uniform), name='w1'
        )

        self.weight2 = self.add_weight(
            shape=(input_shape[-1], self.num_modes, self.modes1, self.modes2), dtype=tf.complex64,
            initializer = complex_initializer(tf.keras.initializers.glorot_uniform), name='w2'
        )

    def compl_mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return tf.einsum("bixy,ioxy->boxy", input, weights)

    def call(self, X):

        # Name definition
        FFT_name = 'fft-layer' + str(self.stage)
        RFFT_name = 'ifft-layer' + str(self.stage)

        Res_X = tf.keras.layers.Conv2D(filters = self.num_modes, kernel_size = (1, 1), padding = 'same')(X)

        X = tf.transpose(X, perm=[0, 3, 1, 2])
        X_fft = tf.signal.rfft2d(X, name = FFT_name)

        updated_slice = self.compl_mul2d(X_fft[:, :, :self.modes1, :self.modes2], self.weight1)
        updated_slice2 = self.compl_mul2d(X_fft[:, :, -self.modes1:, :self.modes2], self.weight2)

        zero_0 = tf.zeros([tf.shape(X)[0], tf.shape(X)[1], tf.shape(X)[2]-2*self.modes1, self.modes2], dtype=tf.complex64)
        zero_1 = tf.zeros([tf.shape(X)[0], tf.shape(X)[1], tf.shape(X)[2], tf.shape(X)[3]//2+1-self.modes2], dtype=tf.complex64)
        out_ft = tf.concat([tf.concat([updated_slice, zero_0, updated_slice2], axis=2), zero_1], axis=3)

        X = tf.signal.irfft2d(out_ft, fft_length=(X.shape[2], X.shape[3]), name = RFFT_name)
        X = tf.transpose(X, perm=[0, 2, 3, 1])

        X = tf.keras.layers.Add()([X, Res_X])

        X = tf.keras.layers.Activation('relu')(X)

        return X

def FNO_large(input_shape):

    X_input = tf.keras.layers.Input(shape = input_shape)


    X = P(X_input, F1 = 64, k_size = 1, s = 1, stage = 1)

    X = FourierLayer_large(64, stage = 1)(X)
    X = FourierLayer_large(64, stage = 2)(X)
    X = FourierLayer_large(64, stage = 3)(X)
    X = FourierLayer_large(64, stage = 4)(X)

    X = Q(X, F1 = 64, k_size = 1, s = 1, stage = 1)

    X = tf.keras.layers.Dense(2, activation=tf.nn.softmax, kernel_initializer = tf.keras.initializers.glorot_uniform(seed=0), name = 'Dense')(X)

    # Create model
    model = tf.keras.Model(inputs = X_input, outputs = X, name = 'Fourier-Neural-Operator')

    return model

# %%
BATCH_SIZE = 3
u_optimizer = tf.keras.optimizers.Adam(1e-4)

u_model = FNO_large(input_shape = (400, 400, 4))

# %%
import time

def train_step(t_images, t_labels):
    ce_loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
    with tf.GradientTape() as u_tape:
        prob = u_model(t_images, training=True)
        loss = ce_loss(t_labels, prob)
    gradients_of_u_model = u_tape.gradient(loss, u_model.trainable_variables)
    u_optimizer.apply_gradients(zip(gradients_of_u_model, u_model.trainable_variables))
    return prob


def train(train_ds, epoch):
    train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')
    for (t_images, t_labels) in train_ds:

        logits = train_step(t_images, t_labels)
        train_accuracy.update_state(t_labels, logits)
        # print(train_accuracy.result())

    train_acc = train_accuracy.result()
    print('train accuracy over epoch %d: %.2f'% (epoch+1, train_acc*100))

    return

# %%
folder = ['/content/drive/MyDrive/ice_cloud/l8ps_ds_2', '/content/drive/MyDrive/ice_cloud/l8ps_ds_3',
          '/content/drive/MyDrive/ice_cloud/l8ps_ds_4', '/content/drive/MyDrive/ice_cloud/l8ps_ds_5',
          '/content/drive/MyDrive/ice_cloud/l8ps_ds_6']
filenames = [os.path.join(folder[0], f) for f in os.listdir(folder[0]) if f.endswith('.tfrecords') and not f.endswith('full.tfrecords')]+\
            [os.path.join(folder[1], f) for f in os.listdir(folder[1]) if f.endswith('.tfrecords') and not f.endswith('full.tfrecords')]+\
            [os.path.join(folder[2], f) for f in os.listdir(folder[2]) if f.endswith('.tfrecords') and not f.endswith('full.tfrecords')]+\
            [os.path.join(folder[3], f) for f in os.listdir(folder[3]) if f.endswith('.tfrecords') and not f.endswith('full.tfrecords')]+\
            [os.path.join(folder[4], f) for f in os.listdir(folder[4]) if f.endswith('.tfrecords') and not f.endswith('full.tfrecords')]

filenames
# Out:
# ['/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230308_212634_27_2413.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230325_103503_19_240c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230329_033637_63_2414.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230402_144322_97_2402.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230417_072528_39_2414.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230418_094613_93_2426.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230418_094636_32_2426.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230420_143108_00_2413.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230429_192205_75_2414.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230429_192219_98_2414.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230503_122053_44_2414.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230515_223754_57_240c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230515_223756_60_240c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230515_223758_63_240c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_2/20230609_155647_20_2402.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230617_213515_19_2440.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230627_235127_21_2460.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230629_220048_88_2439.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230629_220021_34_2439.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230702_192016_98_2426.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230704_005232_37_24ba.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230704_005237_09_24ba.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230705_230231_12_242b.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230706_021744_19_2489.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230706_021830_37_2489.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230708_215448_75_24ba.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_3/20230708_215514_37_24ba.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230714_193906_07_2490.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230714_112730_21_2489.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230719_181822_98_2458.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230719_000904_99_247a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230720_190412_94_227a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230720_204136_10_2488.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230720_204148_94_2488.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230722_004053_48_24c7.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230725_192011_53_2431.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230802_183522_41_247b.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_4/20230805_190516_61_2478.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230805_190317_50_24af.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230805_190315_23_24af.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230811_165140_14_2426.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230812_222541_19_24b5.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230817_062015_26_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230818_201007_84_24c9.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230819_173556_56_24bc.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230819_173601_07_24bc.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230826_174752_21_2402.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230827_165217_36_2477.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230827_165215_19_2477.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_5/20230829_195324_85_24a7.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230902_161453_57_2402.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230904_210206_16_249a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230910_233941_60_2482.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230910_234141_76_2482.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230915_190012_94_249a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230917_004308_01_24a4.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230917_004305_88_24a4.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230918_111524_54_2426.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230919_034530_13_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230920_160237_28_227a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230920_160247_89_227a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230920_160252_14_227a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230920_160258_51_227a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230920_160349_45_227a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230924_104348_17_2486.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230927_025716_57_247a.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230927_210514_80_24a4.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230927_210523_24_24a4.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230927_210525_18_24a4.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230929_010549_30_2483.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230929_010551_41_2483.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230929_010745_27_2483.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230929_010808_46_2483.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230929_010842_03_2483.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230929_155644_66_2490.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230929_155648_88_2490.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230930_001041_93_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230930_001050_22_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230930_001102_67_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230930_001110_96_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230930_001119_26_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20230930_001200_57_249c.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231004_062122_41_2473.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231005_034856_88_247d.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231005_034903_19_247d.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231006_192023_01_2481.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231006_192027_14_2481.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231006_192031_26_2481.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231006_192043_63_2481.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231007_051435_87_2461.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231010_235359_22_2473.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231012_103105_37_2483.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231012_103147_17_2483.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231013_224519_40_2498.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231013_224521_54_2498.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231024_024228_29_2479.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231025_195347_41_2461.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231025_195355_76_2461.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231025_195416_64_2461.tfrecords',
#  '/content/drive/MyDrive/ice_cloud/l8ps_ds_6/20231029_061749_34_247a.tfrecords']

# %%
def train_process():
    train_ds = input_pipeline(filenames, BATCH_SIZE, is_repeat=False)

    for i in range(100):
        train(train_ds, i)
        if (i + 1) % 1 == 0:
            u_model.save_weights('FourierNet.ckpt')

train_process()

# %%
u_model = FNO_large(input_shape = (400, 400, 4))
u_model.load_weights('/content/drive/MyDrive/ice_cloud/github_code/FourierNet.ckpt')

# %%
def tif2array(input_file):
    dataset = gdal.Open(input_file, gdal.GA_ReadOnly)
    image = np.zeros((dataset.RasterYSize, dataset.RasterXSize, dataset.RasterCount),
                     dtype=int)

    for b in range(dataset.RasterCount):
        band = dataset.GetRasterBand(b + 1)
        image[:, :, b] = band.ReadAsArray()

    return image

def clip_center(img, clip_height, clip_width):
    """
    Clips the center part of the image.

    Parameters:
    - img: 2D or 3D NumPy array representing the image.
    - clip_height: Height of the central clip.
    - clip_width: Width of the central clip.

    Returns:
    - Clipped center part of the image as a NumPy array.
    """
    # Get image dimensions
    img_height, img_width = img.shape[:2]

    # Calculate the center coordinates
    center_y, center_x = img_height // 2, img_width // 2

    # Define the starting and ending points for the clipping
    start_y = max(center_y - clip_height // 2, 0)
    end_y = min(center_y + clip_height // 2, img_height)
    start_x = max(center_x - clip_width // 2, 0)
    end_x = min(center_x + clip_width // 2, img_width)

    # Return the clipped center part
    return img[start_y:end_y, start_x:end_x]

# %%
folder_path = '/content/drive/MyDrive/ice_cloud/test_ds/dataset'
imgs = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('ref.tif')]
imgs.sort()

folder_path = '/content/drive/MyDrive/ice_cloud/test_ds2/dataset'
imgs2 = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('ref.tif')]
imgs2.sort()
imgs = imgs+imgs2
imgs
# Out:
# ['/content/drive/MyDrive/ice_cloud/test_ds/dataset/2022-04-15_strip_5573346_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-08-31_strip_6747657_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-09-09_strip_6763305_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-09-14_strip_6774056_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-09-20_strip_6786319_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-09-21_strip_6788017_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-09-24_strip_6793653_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-09-27_strip_6800261_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-10-06_strip_6818915_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-10-08_strip_6823217_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-10-13_strip_6833728_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/2023-10-21_strip_6850630_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230326_125813_33_2414_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230605_180402_17_24b9_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230628_181322_09_2483_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230714_122052_75_2420_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230730_164107_17_2451_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230811_233440_48_24ca_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230924_111938_48_2498_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230927_151159_71_248c_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20230929_152505_32_24a4_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20231007_115205_97_24a7_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20231011_115326_82_24ca_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20231011_143246_86_2447_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20240228_095256_10_24c7_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20240304_095120_53_24c3_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20240307_124142_64_248c_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20240315_102703_99_2473_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20240316_105507_35_247b_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds/dataset/20240330_171110_24_24df_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20230623_102054_28_24c7_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20230712_060933_71_24ce_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240614_052655_73_24f2_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240615_212933_55_24a1_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240615_215901_39_247a_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240618_093220_48_24c4_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240619_074554_34_24c2_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240627_081947_32_24fd_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240706_010617_85_2460_ref.tif',
#  '/content/drive/MyDrive/ice_cloud/test_ds2/dataset/20240720_120151_42_24a1_ref.tif']

# %%
for img_path in imgs[2:3]:
    img = tif2array(img_path)
    img = clip_center(img, 3200, 3200)

    img = img/10000

    img = tf.reshape(img, [1, 3200, 3200, 4])

    patch_size = 400
    stride = 400
    output_shape = (img.shape[1], img.shape[2])

    # Initialize an empty array for storing the full prediction
    full_prediction = np.zeros(output_shape)

    # Iterate over the image with a sliding window
    for i in range(0, img.shape[1], stride):
        for j in range(0, img.shape[2], stride):
            patch = img[:, i:i+patch_size, j:j+patch_size, :]

            if patch.shape[1] == patch_size and patch.shape[2] == patch_size:
                pred = u_model(patch, training=False)

                # Place the predicted patch back into the full prediction array
                full_prediction[i:i+patch_size, j:j+patch_size] = pred[0, :, :, 1]

    plt.figure(figsize=(10, 10))

    plt.subplot(1, 2, 1)
    plt.axis('off')
    plt.imshow((img[0, ::10, ::10, 2::-1]), vmin=0, vmax=1)

    plt.subplot(1, 2, 2)
    plt.axis('off')
    plt.imshow((full_prediction), vmin=0, vmax=1)

    # np.save(img_path[:-7]+'fouriernet.npy', full_prediction)
